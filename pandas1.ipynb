# %%
import pandas as pd

# %%
x=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/hotel_bookings.csv")

# %%
x.head
# Out:
# <bound method NDFrame.head of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
x.tail
# Out:
# <bound method NDFrame.tail of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
x.sample()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 36866  Resort Hotel            0        309               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 36866                May                        21                         25
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 36866                        2                     5       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 36866    No Deposit   40.0     NaN                    0      Contract  68.7
#
#        required_car_parking_spaces  total_of_special_requests  \
# 36866                            0                          2
#
#        reservation_status reservation_status_date
# 36866           Check-Out              06-01-2017
#
# [1 rows x 32 columns]

# %%
x.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
x.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
x.describe
# Out:
# <bound method NDFrame.describe of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
x.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
x.shape
# Out:
# (119390, 32)

# %%
import pandas as pd
import numpy as np

# %%
lables=['w','x','y','z']
sample_list=[100,200,300,400]
array=np.array([1,2,3,4])
dict={'w':10,'x':20,'y':30,'z':40}

# %%
lables
# Out:
# ['w', 'e', 'x', 't']

# %%
type(lables)
# Out:
# list

# %%
pd.Series(data=sample_list)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
pd.Series(data=sample_list,index=lables)
# Out:
# w    100
# x    200
# y    300
# z    400
# dtype: int64

# %%
pd.Series(sample_list,array)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# dtype: int64

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['cricke','football','basketball','golf'])

# %%
sports1
# Out:
# cricke        1
# football      2
# basketball    3
# golf          4
# dtype: int64

# %%
sports2=pd.Series([11,2,3,4],index=['cricket','football','baksetball','golf'])

# %%
sports2
# Out:
# cricket       11
# football       2
# baksetball     3
# golf           4
# dtype: int64

# %%
sports2['cricket']
# Out:
# 11

# %%
sports1+sports2
# Out:
# baksetball    NaN
# basketball    NaN
# cricke        NaN
# cricket       NaN
# football      4.0
# golf          8.0
# dtype: float64

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H'.split(),columns='score1 score2 score3 score4 score5'.split())

# %%
df1
# Out:
#      score1    score2    score3    score4    score5
# A  0.000027  0.774079  0.553997  0.281520  0.718964
# B  0.185401  0.618782  0.629045  0.214925  0.408494
# C  0.627662  0.873291  0.517212  0.486712  0.211147
# D  0.810965  0.339808  0.941840  0.666634  0.984451
# E  0.608603  0.646787  0.882713  0.281964  0.750115
# F  0.389801  0.443801  0.058821  0.403186  0.853824
# G  0.203435  0.219217  0.498916  0.768848  0.085265
# H  0.114504  0.454981  0.393714  0.775458  0.772682

# %%
df1["score3"]
# Out:
# A    0.553997
# B    0.629045
# C    0.517212
# D    0.941840
# E    0.882713
# F    0.058821
# G    0.498916
# H    0.393714
# Name: score3, dtype: float64

# %%
df1[["score1","score2","score3"]]
# Out:
#      score1    score2    score3
# A  0.000027  0.774079  0.553997
# B  0.185401  0.618782  0.629045
# C  0.627662  0.873291  0.517212
# D  0.810965  0.339808  0.941840
# E  0.608603  0.646787  0.882713
# F  0.389801  0.443801  0.058821
# G  0.203435  0.219217  0.498916
# H  0.114504  0.454981  0.393714

# %%
df1['score5']+df1['score1']
# Out:
# A    0.718991
# B    0.593894
# C    0.838809
# D    1.795416
# E    1.358718
# F    1.243625
# G    0.288700
# H    0.887186
# dtype: float64

# %%
df2={'ID':['101','101','102','103','104'],'Name':['john','merry','Akash','Kalvin','lilly'],'profit':[20,40,30,50,66]}
df=pd.DataFrame(df2)

# %%
df
# Out:
#     ID    Name  profit
# 0  101    john      20
# 1  101   merry      40
# 2  102   Akash      30
# 3  103  Kalvin      50
# 4  104   lilly      66

# %%
df["ID"]
# Out:
# 0    101
# 1    101
# 2    102
# 3    103
# 4    104
# Name: ID, dtype: object

# %%
df[["ID",axis=1]]
# Out:
#   File "<ipython-input-59-6c397d4272db>", line 1
#     df[["ID",axis=1]]
#                  ^
# SyntaxError: invalid syntax

# %%
df=df.drop("ID",axis=1)

# %%
df
# Out:
#      Name  profit
# 0    john      20
# 1   merry      40
# 2   Akash      30
# 3  Kalvin      50
# 4   lilly      66

# %%
df.drop(3)
# Out:
#     Name  profit
# 0   john      20
# 1  merry      40
# 2  Akash      30
# 4  lilly      66

# %%
df.drop(2,axis=0)
# Out:
#      Name  profit
# 0    john      20
# 1   merry      40
# 3  Kalvin      50
# 4   lilly      66
